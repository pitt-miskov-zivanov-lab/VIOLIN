# %% [markdown]
# ## Proofreading
# Due to the ambiguous of the biological terminology, information might be misread by VIOLIN. To avoid this problem, please check your files to meet the standard that VIOLIN proceed.
# Although VIOLIN follows the BioRECIPE format, we provide several format checker to help the files read correctly. Below is an example to check your customized files.

# %% [markdown]
# 1. Check the model file
#
# This step will:
# - check the existence of the regulators.
# - check the uniqueness of the elements in the model file.
# - check the uniqueness of regulators for every element.
# - check the correspondence of connection type of regulators.

# %%
# !python normalization.py --format model --file ../examples/input/models/modelA_biorecipe.xlsx

# %% [markdown]
# 2. Check the reading file
#
# This step will normalize the regulator/regulated name, id, database, hgnc symbol columns

# %%
# !python normalization.py --format model 
                        --file ../examples/input/interactions/example/RA2_reading_BioRECIPE.xlsx 
                        --selected_columns Regulated,Regulator --outdir ./RA2_reading_BioRCEIPE_normalized.xlsx
